# %% [markdown]
# <a href="https://colab.research.google.com/github/ishabansal2512/assignment/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sps


import matplotlib as mpl
import matplotlib.pyplot as plt
% matplotlib inline


x= np.arange(0,10)
y= np.arange(11,21)
plt.plot (x,y)
plt.title('line plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')



c= np.arange(1,11)
d= 3 * x + 5
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(x,y)


a = np.arange(0 , 4 * np.pi, 0.1)
b = np.sin(a)
plt.title("sin waveform")

plt.plot(x , y , color='b')
plt.show()

# %%
a = np.arange(0 , 4 * np.pi, 0.1)
b = np.sin(a)
plt.title("sin waveform")

plt.plot(a , b , color='b')
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(c,d,'r--')
plt.subplot(2,2,2)
plt.plot(c,d,'g*--')
plt.subplot(2,2,3)
plt.plot(c,d,'bo')
plt.subplot(2,2,4)
plt.plot(c,d,'go')

# %%
import matplotlib.pyplot as plt
days = [1,2,3,4,5,6,7]
sales1 = [160,150,140,145,175,165,180]
plt.plot (days, sales1)
